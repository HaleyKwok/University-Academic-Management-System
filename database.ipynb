# %%
# %load_ext sql

# %%
# %sql sqlite:///myuniversity.db

# %%
from sqlalchemy import create_engine, Column, Integer, String, DECIMAL, Date, Time, ForeignKey, Text
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker, relationship

# %%
Base = declarative_base()

class Department(Base):
    __tablename__ = 'Department'
    dept_name = Column(String(50), primary_key=True)
    building = Column(String(50))
    budget = Column(DECIMAL(12, 2))

class Course(Base):
    __tablename__ = 'Course'
    course_ID = Column(String(10), primary_key=True)
    title = Column(String(100))
    dept_name = Column(String(50), ForeignKey('Department.dept_name'))
    credits = Column(Integer)
    syllabus = Column(Text)
    department = relationship("Department", back_populates="courses")
    prerequisites = relationship("Prerequisite", foreign_keys="[Prerequisite.course_ID]",
                                 back_populates="course")
    prerequisites_for = relationship("Prerequisite", foreign_keys="[Prerequisite.prereq_ID]",
                                     back_populates="prerequisite")

Department.courses = relationship("Course", order_by=Course.course_ID, back_populates="department")

class Instructor(Base):
    __tablename__ = 'Instructor'
    ID = Column(String(10), primary_key=True)
    name = Column(String(100))
    dept_name = Column(String(50), ForeignKey('Department.dept_name'))
    salary = Column(DECIMAL(12, 2))
    department = relationship("Department", back_populates="instructors")

Department.instructors = relationship("Instructor", order_by=Instructor.ID, back_populates="department")

class Section(Base):
    __tablename__ = 'Section'
    sec_ID = Column(String(10), primary_key=True)
    course_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    semester = Column(String(10), primary_key=True)
    year = Column(Integer, primary_key=True)
    building = Column(String(50))
    room_no = Column(String(10))
    time_slot_ID = Column(String(10), ForeignKey('Time_Slot.time_slot_ID'))

class Time_Slot(Base):
    __tablename__ = 'Time_Slot'
    time_slot_ID = Column(String(10), primary_key=True)
    day = Column(String(10))
    start_hr = Column(Time)
    end_hr = Column(Time)
    start_min = Column(Time)
    end_min = Column(Time)

class Classroom(Base):
    __tablename__ = 'Classroom'
    room_no = Column(String(10), primary_key=True)
    building = Column(String(50), primary_key=True)
    capacity = Column(Integer)

Section.classroom = relationship("Classroom", foreign_keys=[Section.building, Section.room_no], backref="sections")

class Student(Base):
    __tablename__ = 'Student'
    ID = Column(String(10), primary_key=True)
    name = Column(String(100))
    dept_name = Column(String(50), ForeignKey('Department.dept_name'))
    tot_credit = Column(Integer)
    date_of_birth = Column(Date)

Department.students = relationship("Student", order_by=Student.ID, back_populates="department")

class Advisor(Base):
    __tablename__ = 'Advisor'
    s_ID = Column(String(10), ForeignKey('Student.ID'), primary_key=True)
    I_ID = Column(String(10), ForeignKey('Instructor.ID'))

class Takes(Base):
    __tablename__ = 'Takes'
    ID = Column(String(10), ForeignKey('Student.ID'), primary_key=True)
    course_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    sec_ID = Column(String(10), primary_key=True)
    semester = Column(String(10), primary_key=True)
    year = Column(Integer, primary_key=True)
    grade = Column(String(2))

class Teaches(Base):
    __tablename__ = 'Teaches'
    ID = Column(String(10), ForeignKey('Instructor.ID'), primary_key=True)
    course_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    sec_ID = Column(String(10), primary_key=True)
    semester = Column(String(10), primary_key=True)
    year = Column(Integer, primary_key=True)

class Prerequisite(Base):
    __tablename__ = 'Prerequisite'
    course_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    prereq_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    course = relationship("Course", foreign_keys=[course_ID], back_populates="prerequisites")
    prerequisite = relationship("Course", foreign_keys=[prereq_ID], back_populates="prerequisites_for")

class Grading_Components(Base):
    __tablename__ = 'Grading_Components'
    course_ID = Column(String(10), ForeignKey('Course.course_ID'), primary_key=True)
    max_points = Column(Integer)
    weights = Column(DECIMAL(5, 2))
    course = relationship("Course", back_populates="grading_components")

Course.grading_components = relationship("Grading_Components", uselist=False, back_populates="course")

# Set up the database engine
engine = create_engine('sqlite:///:memory:', echo=True)

# Create all tables in the engine
Base.metadata.create_all(engine)
# Out:
# 2024-04-27 22:05:01,451 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2024-04-27 22:05:01,452 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Department")
# 2024-04-27 22:05:01,452 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,453 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Department")
# 2024-04-27 22:05:01,453 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,454 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Course")
# 2024-04-27 22:05:01,454 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,455 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Course")
# 2024-04-27 22:05:01,455 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,456 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Instructor")
# 2024-04-27 22:05:01,456 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,457 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Instructor")
# 2024-04-27 22:05:01,457 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,458 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Section")
# 2024-04-27 22:05:01,458 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,458 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Section")
# 2024-04-27 22:05:01,458 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,459 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Time_Slot")
# 2024-04-27 22:05:01,459 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,460 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Time_Slot")
# 2024-04-27 22:05:01,460 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,461 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Classroom")
# 2024-04-27 22:05:01,461 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,462 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Classroom")
# 2024-04-27 22:05:01,462 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,462 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Student")
# 2024-04-27 22:05:01,462 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,463 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Student")
# 2024-04-27 22:05:01,463 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,463 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Advisor")
# 2024-04-27 22:05:01,464 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,464 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Advisor")
# 2024-04-27 22:05:01,465 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,465 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Takes")
# 2024-04-27 22:05:01,465 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Takes")
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Teaches")
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Teaches")
# 2024-04-27 22:05:01,466 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,467 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Prerequisite")
# 2024-04-27 22:05:01,467 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,467 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Prerequisite")
# 2024-04-27 22:05:01,467 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,467 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("Grading_Components")
# 2024-04-27 22:05:01,468 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,468 INFO sqlalchemy.engine.Engine PRAGMA temp.table_info("Grading_Components")
# 2024-04-27 22:05:01,468 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2024-04-27 22:05:01,470 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Department" (
# 	dept_name VARCHAR(50) NOT NULL,
# 	building VARCHAR(50),
# 	budget DECIMAL(12, 2),
# 	PRIMARY KEY (dept_name)
# )
#
#
# 2024-04-27 22:05:01,470 INFO sqlalchemy.engine.Engine [no key 0.00035s] ()
# 2024-04-27 22:05:01,471 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Time_Slot" (
# 	"time_slot_ID" VARCHAR(10) NOT NULL,
# 	day VARCHAR(10),
# 	start_hr TIME,
# 	end_hr TIME,
# 	start_min TIME,
# 	end_min TIME,
# 	PRIMARY KEY ("time_slot_ID")
# )
#
#
# 2024-04-27 22:05:01,471 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-04-27 22:05:01,472 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Classroom" (
# 	room_no VARCHAR(10) NOT NULL,
# 	building VARCHAR(50) NOT NULL,
# 	capacity INTEGER,
# 	PRIMARY KEY (room_no, building)
# )
#
#
# 2024-04-27 22:05:01,472 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-04-27 22:05:01,473 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Course" (
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	title VARCHAR(100),
# 	dept_name VARCHAR(50),
# 	credits INTEGER,
# 	syllabus TEXT,
# 	PRIMARY KEY ("course_ID"),
# 	FOREIGN KEY(dept_name) REFERENCES "Department" (dept_name)
# )
#
#
# 2024-04-27 22:05:01,473 INFO sqlalchemy.engine.Engine [no key 0.00049s] ()
# 2024-04-27 22:05:01,474 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Instructor" (
# 	"ID" VARCHAR(10) NOT NULL,
# 	name VARCHAR(100),
# 	dept_name VARCHAR(50),
# 	salary DECIMAL(12, 2),
# 	PRIMARY KEY ("ID"),
# 	FOREIGN KEY(dept_name) REFERENCES "Department" (dept_name)
# )
#
#
# 2024-04-27 22:05:01,474 INFO sqlalchemy.engine.Engine [no key 0.00023s] ()
# 2024-04-27 22:05:01,475 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Student" (
# 	"ID" VARCHAR(10) NOT NULL,
# 	name VARCHAR(100),
# 	dept_name VARCHAR(50),
# 	tot_credit INTEGER,
# 	date_of_birth DATE,
# 	PRIMARY KEY ("ID"),
# 	FOREIGN KEY(dept_name) REFERENCES "Department" (dept_name)
# )
#
#
# 2024-04-27 22:05:01,475 INFO sqlalchemy.engine.Engine [no key 0.00022s] ()
# 2024-04-27 22:05:01,476 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Section" (
# 	"sec_ID" VARCHAR(10) NOT NULL,
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	semester VARCHAR(10) NOT NULL,
# 	year INTEGER NOT NULL,
# 	building VARCHAR(50),
# 	room_no VARCHAR(10),
# 	"time_slot_ID" VARCHAR(10),
# 	PRIMARY KEY ("sec_ID", "course_ID", semester, year),
# 	FOREIGN KEY("course_ID") REFERENCES "Course" ("course_ID"),
# 	FOREIGN KEY("time_slot_ID") REFERENCES "Time_Slot" ("time_slot_ID")
# )
#
#
# 2024-04-27 22:05:01,476 INFO sqlalchemy.engine.Engine [no key 0.00025s] ()
# 2024-04-27 22:05:01,477 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Advisor" (
# 	"s_ID" VARCHAR(10) NOT NULL,
# 	"I_ID" VARCHAR(10),
# 	PRIMARY KEY ("s_ID"),
# 	FOREIGN KEY("s_ID") REFERENCES "Student" ("ID"),
# 	FOREIGN KEY("I_ID") REFERENCES "Instructor" ("ID")
# )
#
#
# 2024-04-27 22:05:01,477 INFO sqlalchemy.engine.Engine [no key 0.00030s] ()
# 2024-04-27 22:05:01,478 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Takes" (
# 	"ID" VARCHAR(10) NOT NULL,
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	"sec_ID" VARCHAR(10) NOT NULL,
# 	semester VARCHAR(10) NOT NULL,
# 	year INTEGER NOT NULL,
# 	grade VARCHAR(2),
# 	PRIMARY KEY ("ID", "course_ID", "sec_ID", semester, year),
# 	FOREIGN KEY("ID") REFERENCES "Student" ("ID"),
# 	FOREIGN KEY("course_ID") REFERENCES "Course" ("course_ID")
# )
#
#
# 2024-04-27 22:05:01,478 INFO sqlalchemy.engine.Engine [no key 0.00020s] ()
# 2024-04-27 22:05:01,479 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Teaches" (
# 	"ID" VARCHAR(10) NOT NULL,
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	"sec_ID" VARCHAR(10) NOT NULL,
# 	semester VARCHAR(10) NOT NULL,
# 	year INTEGER NOT NULL,
# 	PRIMARY KEY ("ID", "course_ID", "sec_ID", semester, year),
# 	FOREIGN KEY("ID") REFERENCES "Instructor" ("ID"),
# 	FOREIGN KEY("course_ID") REFERENCES "Course" ("course_ID")
# )
#
#
# 2024-04-27 22:05:01,479 INFO sqlalchemy.engine.Engine [no key 0.00037s] ()
# 2024-04-27 22:05:01,480 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Prerequisite" (
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	"prereq_ID" VARCHAR(10) NOT NULL,
# 	PRIMARY KEY ("course_ID", "prereq_ID"),
# 	FOREIGN KEY("course_ID") REFERENCES "Course" ("course_ID"),
# 	FOREIGN KEY("prereq_ID") REFERENCES "Course" ("course_ID")
# )
#
#
# 2024-04-27 22:05:01,481 INFO sqlalchemy.engine.Engine [no key 0.00077s] ()
# 2024-04-27 22:05:01,482 INFO sqlalchemy.engine.Engine
# CREATE TABLE "Grading_Components" (
# 	"course_ID" VARCHAR(10) NOT NULL,
# 	max_points INTEGER,
# 	weights DECIMAL(5, 2),
# 	PRIMARY KEY ("course_ID"),
# 	FOREIGN KEY("course_ID") REFERENCES "Course" ("course_ID")
# )
#
#
# 2024-04-27 22:05:01,482 INFO sqlalchemy.engine.Engine [no key 0.00026s] ()
# 2024-04-27 22:05:01,483 INFO sqlalchemy.engine.Engine COMMIT
# /var/folders/tf/6tszc4p95dn6fjrhhsz6w6380000gn/T/ipykernel_23456/3660679694.py:1: MovedIn20Warning: The ``declarative_base()`` function is now available as sqlalchemy.orm.declarative_base(). (deprecated since: 2.0) (Background on SQLAlchemy 2.0 at: https://sqlalche.me/e/b8d9)
#   Base = declarative_base()

# %%
Session = sessionmaker(bind=engine)
session = Session()

# Sample data for the Department table
departments = [
    Department(dept_name="Computer Science", building="CompSci Building", budget=500000.00),
    Department(dept_name="Mathematics", building="Math Building", budget=300000.00),
    Department(dept_name="Physics", building="Physics Building", budget=250000.00),
    Department(dept_name="History", building="History Building", budget=200000.00),
    Department(dept_name="English", building="English Building", budget=150000.00),
    Department(dept_name="Biology", building="Biology Building", budget=350000.00),
    Department(dept_name="Chemistry", building="Chemistry Building", budget=360000.00),
    Department(dept_name="Economics", building="Economics Building", budget=400000.00),
    Department(dept_name="Law", building="Law Building", budget=600000.00),
    Department(dept_name="Psychology", building="Psychology Building", budget=220000.00)
]
session.add_all(departments)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:2509, in Mapper.get_property(self, key, _configure_mappers)
#    2508 try:
# -> 2509     return self._props[key]
#    2510 except KeyError as err:
#
# KeyError: 'department'
#
# The above exception was the direct cause of the following exception:
#
# InvalidRequestError                       Traceback (most recent call last)
# Cell In[5], line 6
#       2 session = Session()
#       4 # Sample data for the Department table
#       5 departments = [
# ----> 6     Department(dept_name="Computer Science", building="CompSci Building", budget=500000.00),
#       7     Department(dept_name="Mathematics", building="Math Building", budget=300000.00),
#       8     Department(dept_name="Physics", building="Physics Building", budget=250000.00),
#       9     Department(dept_name="History", building="History Building", budget=200000.00),
#      10     Department(dept_name="English", building="English Building", budget=150000.00),
#      11     Department(dept_name="Biology", building="Biology Building", budget=350000.00),
#      12     Department(dept_name="Chemistry", building="Chemistry Building", budget=360000.00),
#      13     Department(dept_name="Economics", building="Economics Building", budget=400000.00),
#      14     Department(dept_name="Law", building="Law Building", budget=600000.00),
#      15     Department(dept_name="Psychology", building="Psychology Building", budget=220000.00)
#      16 ]
#      17 session.add_all(departments)
#
# File <string>:4, in __init__(self, **kwargs)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/state.py:559, in InstanceState._initialize_instance(*mixed, **kwargs)
#     556 self, instance, args = mixed[0], mixed[1], mixed[2:]  # noqa
#     557 manager = self.manager
# --> 559 manager.dispatch.init(self, args, kwargs)
#     561 try:
#     562     manager.original_init(*mixed[1:], **kwargs)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/event/attr.py:497, in _CompoundListener.__call__(self, *args, **kw)
#     495     fn(*args, **kw)
#     496 for fn in self.listeners:
# --> 497     fn(*args, **kw)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:4395, in _event_on_init(state, args, kwargs)
#    4393 instrumenting_mapper = state.manager.mapper
#    4394 if instrumenting_mapper:
# -> 4395     instrumenting_mapper._check_configure()
#    4396     if instrumenting_mapper._set_polymorphic_identity:
#    4397         instrumenting_mapper._set_polymorphic_identity(state)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:2388, in Mapper._check_configure(self)
#    2380 @util.langhelpers.tag_method_for_warnings(
#    2381     "This warning originated from the `configure_mappers()` process, "
#    2382     "which was invoked automatically in response to a user-initiated "
#    (...)
#    2385 )
#    2386 def _check_configure(self) -> None:
#    2387     if self.registry._new_mappers:
# -> 2388         _configure_registries({self.registry}, cascade=True)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:4203, in _configure_registries(registries, cascade)
#    4197     Mapper.dispatch._for_class(Mapper).before_configured()  # type: ignore # noqa: E501
#    4198     # initialize properties on all mappers
#    4199     # note that _mapper_registry is unordered, which
#    4200     # may randomly conceal/reveal issues related to
#    4201     # the order of mapper compilation
# -> 4203     _do_configure_registries(registries, cascade)
#    4204 finally:
#    4205     _already_compiling = False
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:4244, in _do_configure_registries(registries, cascade)
#    4242 if not mapper.configured:
#    4243     try:
# -> 4244         mapper._post_configure_properties()
#    4245         mapper._expire_memoizations()
#    4246         mapper.dispatch.mapper_configured(mapper, mapper.class_)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:2405, in Mapper._post_configure_properties(self)
#    2402 self._log("initialize prop %s", key)
#    2404 if prop.parent is self and not prop._configure_started:
# -> 2405     prop.init()
#    2407 if prop._configure_finished:
#    2408     prop.post_instrument_class(self)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/interfaces.py:584, in MapperProperty.init(self)
#     577 """Called after all mappers are created to assemble
#     578 relationships between mappers and perform other post-mapper-creation
#     579 initialization steps.
#     580
#     581
#     582 """
#     583 self._configure_started = True
# --> 584 self.do_init()
#     585 self._configure_finished = True
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/relationships.py:1647, in RelationshipProperty.do_init(self)
#    1645 self._check_cascade_settings(self._cascade)
#    1646 self._post_init()
# -> 1647 self._generate_backref()
#    1648 self._join_condition._warn_for_conflicting_sync_targets()
#    1649 super().do_init()
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/relationships.py:2133, in RelationshipProperty._generate_backref(self)
#    2128     mapper._configure_property(
#    2129         backref_key, relationship, warn_for_existing=True
#    2130     )
#    2132 if self.back_populates:
# -> 2133     self._add_reverse_property(self.back_populates)
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/relationships.py:1578, in RelationshipProperty._add_reverse_property(self, key)
#    1577 def _add_reverse_property(self, key: str) -> None:
# -> 1578     other = self.mapper.get_property(key, _configure_mappers=False)
#    1579     if not isinstance(other, RelationshipProperty):
#    1580         raise sa_exc.InvalidRequestError(
#    1581             "back_populates on relationship '%s' refers to attribute '%s' "
#    1582             "that is not a relationship.  The back_populates parameter "
#    1583             "should refer to the name of a relationship on the target "
#    1584             "class." % (self, other)
#    1585         )
#
# File ~/Desktop/INDENG215/Github/University-Academic-Management-System/sql_UAMS/lib/python3.11/site-packages/sqlalchemy/orm/mapper.py:2511, in Mapper.get_property(self, key, _configure_mappers)
#    2509     return self._props[key]
#    2510 except KeyError as err:
# -> 2511     raise sa_exc.InvalidRequestError(
#    2512         f"Mapper '{self}' has no property '{key}'.  If this property "
#    2513         "was indicated from other mappers or configure events, ensure "
#    2514         "registry.configure() has been called."
#    2515     ) from err
#
# InvalidRequestError: Mapper 'Mapper[Student(Student)]' has no property 'department'.  If this property was indicated from other mappers or configure events, ensure registry.configure() has been called.
